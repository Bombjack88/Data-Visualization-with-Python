# %%
# Tasks To do:
# Task 1
#   Import required libraries
#   Read the dataset
# Task 2
#   Create an application layout
#   Add title to the dashboard application using HTML H1 component
# Task 3
#   Add input text box using core input and output components
#   Add the callback decorator and generate the line chart within the callback function.
# Task 4
#   Practice Exercise

# %% [markdown]
# **Callback decorator**
#
# * Input() function takes two parameters:
#
#     - component-id with the value input-year, which is the ID of the input dropdown.
#     - component_property being accessed is the value property, which represents the year entered by the user.
#
# * Output()function takes two parameters:
#
#     - component-id with the value line-plot, which is the id of the output.
#     - component_property being modified is the figure property, which specifies the data and layout of the line plot.
#
# **Callback function**
#
# * Update data parameter of the go.Figure() with the scatter plot.
#         Sample syntax below:
#         go.Scatter(x='----', y='----', mode='-----', marker='----)
#
# * In the go.Scatter() update the parameter as below:
#
#  - Update x as line_data['Month']
#
#  - Update y as line_data['ArrDelay']
#
# * Update mode as lines, and marker as dict(color='green')
#
# * Update fig.update_layout with title, xaxis_title, and yaxis_title parameters.
#
#  - Title as Month vs Average Flight Delay Time
#  - xaxis_title as Month
#  - yaxis_title as ArrDelay

# %%
# Import required libraries
import pandas as pd
import plotly.graph_objects as go
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# Read the airline data into the pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
# Import required libraries
import pandas as pd
import plotly.graph_objects as go
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})
# Create a dash application
app = dash.Dash(__name__)
                               
app.layout = html.Div(children=[ html.H1('Airline Performance Dashboard',style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
                                html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010', 
                                type='number', style={'height':'50px', 'font-size': 35}),], 
                                style={'font-size': 40}),
                                html.Br(),
                                html.Br(),
                                html.Div(dcc.Graph(id='line-plot')),
                                ])

# add callback decorator
@app.callback( Output(component_id='line-plot', component_property='figure'),
               Input(component_id='input-year', component_property='value'))

# Add computation to callback function and return graph

def get_graph(entered_year):
    # Select 2019 data
    df =  airline_data[airline_data['Year']==int(entered_year)]
    
    # Group the data by Month and compute average over arrival delay time.
    line_data = df.groupby('Month')['ArrDelay'].mean().reset_index()
    fig = go.Figure(data=go.Scatter(x=line_data['Month'], y=line_data['ArrDelay'], mode='lines', marker=dict(color='green')))
    fig.update_layout(title='Month vs Average Flight Delay Time', xaxis_title='Month', yaxis_title='ArrDelay')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=False) # coloca o dashboard no ar-> colocar False no jupyter
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Nov/2023 16:24:11] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
#Practice Exercise
#   Title of the application
#   Component to enter input year
#   A chart conveying Total number of flights to the destination state.

# %%
# Import required libraries
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                   encoding = "ISO-8859-1",
                   dtype={'Div1Airport': str, 'Div1TailNum': str, 
                          'Div2Airport': str, 'Div2TailNum': str})

# %%
# Give the title to the dashboard to “Total number of flights to the destination state split by reporting air” using HTML H1 component and font-size as 50.
# Create a dash application
app = dash.Dash(__name__)
                               
app.layout = html.Div(children=[ html.H1('Total number of flights to the destination state split by reporting air',
                                         style={'textAlign': 'center', 'color': '#503D36', 'font-size': 50}),
                                html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010', 
                                type='number', style={'height':'50px', 'font-size': 40}),], 
                                style={'font-size': 40}),
                                html.Br(),
                                html.Br(),
                                html.Div(dcc.Graph(id='bar-plot')),
                                ])

# %%
# Add Callback decorator:
# Update output component id parameter with bar-plot same as the id provided in the dcc.Graph() component and component property as figure.
# Update input component id parameter with input-year same as the id provided in the dcc.Input() component and component property as value.
# Use style parameter and assign font-size as 35 for the whole division.

# Define Callback graph function:
# Group the data by destination state and reporting airline. Compute the total number of flights in each combination
# Use plotly express bar chart function px.bar. Provide input data, x and y axis variables, and a chart title. This will give the total number of flights to the destination state

app = dash.Dash(__name__)
                               
app.layout = html.Div(children=[ html.H1('Total number of flights to the destination state split by reporting air',style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
                                html.Div(["Input Year: ", dcc.Input(id='input-year', value='2010', 
                                type='number', style={'height':'50px', 'font-size': 35}),], 
                                style={'font-size': 40}),
                                html.Br(),
                                html.Br(),
                                html.Div(dcc.Graph(id='bar-plot')),
                                ])

# add callback decorator
@app.callback( Output(component_id='bar-plot', component_property='figure'),
               Input(component_id='input-year', component_property='value'))

# Add computation to callback function and return graph

def get_graph(entered_year):
    
    df =  airline_data[airline_data['Year']==int(entered_year)]
    # Group the data by destination state and reporting airline
    bar_data = df.groupby('DestState')['Flights'].sum().reset_index()
    fig = px.bar(bar_data, x= "DestState", y= "Flights", title='Total number of flights to the destination state split by reporting airline') 
    fig.update_layout(title='Flights to Destination State', xaxis_title='DestState', yaxis_title='Flights')
    return fig        

# Run the app
if __name__ == '__main__':
     app.run_server(debug=False) # coloca o dashboard no ar-> colocar False no jupyter
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Nov/2023 16:51:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:37] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Nov/2023 16:51:37] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [01/Nov/2023 16:51:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:51:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2023 16:58:47] "POST /_dash-update-component HTTP/1.1" 200 -
